     'y': [np.float64(93.0), np.float64(90.94), np.float64(88.88), np.float64(80.65), np.float64(78.59), np.float64(88.19), np.float64(99.86), np.float64(100.55)]},
    {'x': [np.float64(848.96), np.float64(851.71)],
     'y': [np.float64(80.65), np.float64(82.71)]},
    {'x': [np.float64(849.65), np.float64(853.08)],
     'y': [np.float64(97.12), np.float64(99.17)]},
    {'x': [np.float64(862.0), np.float64(874.35)],
     'y': [np.float64(91.63), np.float64(90.94)]},
    {'x': [np.float64(887.39), np.float64(895.62), np.float64(890.82), np.float64(875.72)],
     'y': [np.float64(62.12), np.float64(88.88), np.float64(110.15), np.float64(130.74)]},
]


# files
filename_base = f"konkurs-{INDEX}"
filename_img = f"{filename_base}.png"
filename_data = f"{filename_base}-dane.txt"
filename_summary = f"{filename_base}-podsumowanie.txt"

# statystyki
total_points_interpolated = 0
total_u_size = 0
valid_curves = 0



plt.figure(figsize=(15, 3))
plt.gca().invert_yaxis()

with open(filename_data, "w") as f_data:
    # iterujemy po kazdej narysowanej krzywej
    for idx, curve in enumerate(data_curves):
        # wspolrzedne wezlow interpolacji
        x_nodes = np.array(curve['x'], dtype=float)
        y_nodes = np.array(curve['y'], dtype=float)

        n = len(x_nodes)
        # just in case
        if n < 2: continue
        valid_curves += 1

        # wezly
        t = np.linspace(0, 1, n)

        # NIFS3 (gotowa biblioteczna, implementowałem juz swoja ale wolalem wybrac dooptowaną)
        cs_x = CubicSpline(t, x_nodes, bc_type='natural')
        cs_y = CubicSpline(t, y_nodes, bc_type='natural')

        # liczba punktow do narysowania gladkiej linii
        # biore liczbe wezlow * 8 (lub 30 jezeli wyszloby za malo), by dooptować
        M = max(30, n * 8)

        # siatka punktow
        u = np.linspace(0, 1, M)

        # wygladzone wspolrzedne
        vals_x = cs_x(u)
        vals_y = cs_y(u)

        # rysowanie na wykresie
        plt.plot(vals_x, vals_y, 'b-', linewidth=1.5)

        # formatowanie tablicy na string (funkcja pomocnicza)
        def arr_str(arr): return "[" + ", ".join(f"{v:.4f}" for v in arr) + "]"
        f_data.write(arr_str(x_nodes) + "\n")
        f_data.write(arr_str(y_nodes) + "\n")
        f_data.write(arr_str(t) + "\n")
        f_data.write(arr_str(u) + "\n")
        f_data.write("\n")

        # aktualizacja statystyk
        total_points_interpolated += n
        total_u_size += len(u)

#plt.title(f"{INDEX}", fontsize=10)
plt.axis('equal')
plt.axis('off')
plt.savefig(filename_img, dpi=150, bbox_inches='tight')
plt.show()

with open(filename_summary, "w") as f_sum:
    f_sum.write(f"{valid_curves}, {total_points_interpolated}, {total_u_size}")
